# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Creating Activation Functions

# %%
def relufunc(x):
    return np.where(x>0, x, 0)

def sigmoidfunc(y):
    y1=[]
    for i,a in enumerate(input_1):
        y1.append(1/(1+np.exp(-a)))
    return y1

def tanhfunc(z):
    z1=[]
    for i,a in enumerate(input_1):
        z1.append((np.exp(a) - np.exp(-a))/(np.exp(a)+np.exp(-a)))
    return z1


def tanhfunc1(z):
    return np.tanh(z)


def softmaxfunc(s):
    e= np.exp(s)
    return e/e.sum() # This will calculate the probablity of each item in the list

# %% [markdown]
# # Calculation Softmax

# %%
input_2 = np.array([12,2,5])
softmax_1=softmaxfunc(input_2)
print("Probablity of each item in the array = ", softmax_1)
print("Item having Highest probablity is at index = ",np.argmax(softmax_1))
# Out:
# Probablity of each item in the array =  [9.99043634e-01 4.53565108e-05 9.11009872e-04]
# Item having Highest probablity is at index =  0

# %% [markdown]
# # Creating Other Activation variables

# %%
input_1=np.arange(-10,10,1)

relu_1=relufunc(input_1)

sigmoid_1=sigmoidfunc(input_1)

tanh_1=tanhfunc(input_1)

tanh_2=tanhfunc1(input_1)

# %% [markdown]
# # Ploting RELU function

# %%
xaxis=range(1, len(input_1)+1)
plt.plot(input_1, relu_1, "b", label="relu Function")
plt.title("RELU Function")
plt.xlabel("Input Values Index")
plt.ylabel("Relu Transfromation")
plt.show()

# %% [markdown]
# # Ploting Sigmoid Function

# %%
plt.plot(input_1, sigmoid_1, "b", label="relu Function")
plt.title("Sigmoid Function")
plt.xlabel("Input Values")
plt.ylabel("Sigmoid Transfromation")
plt.show()

# %% [markdown]
# # plot tanh function

# %%
plt.plot(input_1, tanh_1, "b", label="Tanh Function")
plt.title("Tanh Function")
plt.xlabel("Input Values")
plt.ylabel("Tanh Transfromation")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-473b51865359> in <module>
# ----> 1 plt.plot(input_1, tanh_1, "b", label="Tanh Function")
#       2 plt.title("Tanh Function")
#       3 plt.xlabel("Input Values")
#       4 plt.ylabel("Tanh Transfromation")
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.plot(input_1, tanh_2, "b", label="Tanh Function")
plt.title("Tanh Function")
plt.xlabel("Input Values")
plt.ylabel("Tanh Transfromation")
plt.show()
